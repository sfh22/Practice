# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import sentiment_mod as s
# Out:
# 10664

# %%
#consumer key, consumer secret, access token, access secret.
ckey="z4FYtA7sCsz6A57wlTZ2U5Qw3"
csecret="tcWq0MgGaNQkq6Okodqegon9qd5adnfFgkLFMXqSkok9LMlOl0"
atoken="1210030934382325760-030YvZ0QFTssasLWRhPAVtEoobeELM"
asecret="2gICwDULyLqy1523W0gudTB5C4wR1AmdHIkSeh5oObjMs"

# %%
class listener(StreamListener):

    def on_data(self, data):

        all_data = json.loads(data)

        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)

        if confidence*100 >= 80:
            output = open("twitter-out.txt","a")
            output.write(sentiment_value)
            output.write('\n')
            output.close()

        return True

    def on_error(self, status):
        print(status)

# %%
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

# %%
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["CovidVaccine"])
# Out:
# RT @BobAtkins_: Working together we can get New Jerseyeans the #CovidVaccine ASAP. We need active &amp; retired medical professionals (like my… neg 1.0
# RT @MeghUpdates: Nepal Govt approaches India for 12 million doses of  #CovidVaccine , rejects Chinese Offer .
# India likely to agree  ...
# (H… neg 1.0
# RT @RemmyJr7: #StopTorturingSukkurIBA neg 1.0
# RT @DChaurasia2312: अगर सबकुछ मोदी सरकार के प्लान के मुताबिक ही चला तो 13 या 14 जनवरी से देश में कोरोना टीकाकरण अभियान शुरु हो जाएगा
#
# #Coro… neg 1.0
# RT @CovidCommsSA: Wondering when the vaccine will be available for you?
#
# We've got you covered. Check out our latest vaccine rollout graphi… pos 1.0
# RT @MPSUpprEdmonton: #scammers never let up......please, please be careful of any call, text or email from people/addresses you don't know.… neg 0.5714285714285714
# RT @arabnewspk: #Pakistan’s federal cabinet on Tuesday approved the purchase of #COVID19 vaccine on ‘emergency basis’ || #CovidVaccine http… neg 0.5714285714285714
# ...
